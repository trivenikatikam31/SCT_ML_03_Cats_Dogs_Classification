# %%
import zipfile

with zipfile.ZipFile("/content/cat-and-dog.zip", "r") as zip_ref:
    zip_ref.extractall("/content/data")

print("Dataset Extracted Successfully!")
# Out:
# Dataset Extracted Successfully!

# %%
import os

print(os.listdir("/content/data"))
# Out:
# ['training_set', 'test_set']

# %%
# !pip install opencv-python

# %%
import os
import cv2
import numpy as np

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
import os
print(os.listdir("/content/data/training_set"))
# Out:
# ['training_set']

# %%
import os

print(os.listdir("/content/data/training_set/training_set"))
# Out:
# ['cats', 'dogs']

# %%
train_path = "/content/data/training_set"

# %%
train_path = "/content/data/training_set/training_set"

# %%
import os

print(os.listdir("/content/data/test_set"))
# Out:
# ['test_set']

# %%
test_path = "/content/data/test_set/test_set"

# %%
print(os.listdir("/content/data/training_set/training_set"))
# Out:
# ['cats', 'dogs']

# %%
train_path = "/content/data/training_set/training_set"
test_path = "/content/data/test_set/test_set"

# %%
import os
import cv2
import numpy as np

X_train = []
y_train = []

categories = ["cats", "dogs"]

for category in categories:

    folder = os.path.join(train_path, category)

    label = categories.index(category)

    count = 0

    for img in os.listdir(folder):

        if count == 200:
            break

        img_path = os.path.join(folder, img)

        try:
            image = cv2.imread(img_path)
            image = cv2.resize(image, (64,64))
            image = image.flatten()

            X_train.append(image)
            y_train.append(label)

            count += 1

        except:
            pass

X_train = np.array(X_train)
y_train = np.array(y_train)

print(X_train.shape)
# Out:
# (400, 12288)

# %%
X_test = []
y_test = []

for category in categories:

    folder = os.path.join(test_path, category)

    label = categories.index(category)

    count = 0

    for img in os.listdir(folder):

        if count == 100:
            break

        img_path = os.path.join(folder, img)

        try:
            image = cv2.imread(img_path)
            image = cv2.resize(image, (64,64))
            image = image.flatten()

            X_test.append(image)
            y_test.append(label)

            count += 1

        except:
            pass

X_test = np.array(X_test)
y_test = np.array(y_test)

print(X_test.shape)
# Out:
# (200, 12288)

# %%
from sklearn.svm import SVC

model = SVC(kernel="linear")

model.fit(X_train, y_train)

print("Model Trained Successfully!")
# Out:
# Model Trained Successfully!

# %%
prediction = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, prediction)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.505

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.54       100
#            1       0.51      0.44      0.47       100
#
#     accuracy                           0.51       200
#    macro avg       0.51      0.51      0.50       200
# weighted avg       0.51      0.51      0.50       200
